# %% [markdown]
# <a href="https://colab.research.google.com/github/MikolajKasprzyk/data_science_bootcamp/blob/main/05_uczenie_maszynowe_sklearn/05_regresja_wielomianowa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### <a name='a1'></a> Polynomial Regression - Regresja Wielomianowa
# Powszechnym wzorcem stosowanym w uczeniu maszynowym jest użycie modeli liniowych wytrenowanych na nieliniowych funkcjach danych. Podejscie to utrzymuje szybkie działanie metod liniowych i zarazem umożliwia stosowanie metod liniowych dla znacznie szerszego zakresu danych.
#
# Przykładowo, prosta regresja liniowa może zostać zastosowana przez skonstruowanie cech wielomianowych do modelów nieliniowych.
#
# Rozważmy model regresji liniowej:
# $$\hat{y}(w, x) = w_0 + w_1 x_1 + w_2 x_2$$
# Dodając cechy wileomianowe otrzymujemy:
# $$\hat{y}(w, x) = w_0 + w_1 x_1 + w_2 x_2 + w_3 x_1 x_2 + w_4 x_1^2 + w_5 x_2^2$$
# Wyobraźmy sobie teraz nastepujące podstawienie:
# $$z = [1, x_1, x_2, x_1 x_2, x_1^2, x_2^2]$$
# Wrzucając to z powrotem do naszego modelu dotrzymujemy prosty model liniowy:
# $$\hat{y}(w, z) = w_0 + w_1 z_1 + w_2 z_2 + w_3 z_3 + w_4 z_4 + w_5 z_5$$
#
# To implikuje fakt, iż nasz model regresji wielomianowej znajduje się w klasie modeli liniowych i może być rozwiązany za pomocą tych samych technik.
#
# ### Rozważmy model regresji liniowej: $\hat{y}(w,x)=w_0+w_1x_1$

# %%
# losowe dane ale nie liniowe
np.random.seed(0)
X = np.arange(-10, 10, 0.5)
noise = 80 * np.random.randn(40)
y = -X**3 + 10*X**2 - 2*X + 3 + noise
X = X.reshape(40, 1)
_ = plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression
# jak widac takie podejscie nie jest zbyt skuteczne
regressor = LinearRegression()
regressor.fit(X, y)
y_pred = regressor.predict(X)

plt.scatter(X, y)
plt.plot(X, y_pred, c='r')

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.5398062344255777

# %% [markdown]
# Model jest niedouczony (underfitting). Potrzebujemy zwiekszyć złozoność modelu do naszego problemu.
#
# Rozważmy model regresji liniowej:
# $$\hat{y}(w, x) = w_0 + w_1 x_1$$
# Dodając cechy wielomianowe otrzymujemy:
# $$\hat{y}(w, x) = w_0 + w_1 x_1 +w_2x_1^2 $$
# Wyobraźmy sobie teraz nastepujące podstawienie:
# $$z = [1, x_1, x_1^2]$$
# Wrzucając to z powrotem do naszego modelu otrzymujemy prosty model liniowy:
# $$\hat{y}(w, z) = w_0 + w_1 z_1 + w_2 z_2$$

# %% [markdown]
# ## Ekstracja cech wielomianowych - stopien 2

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2) #wielomian 2go stopnia
X_poly = poly.fit_transform(X) #przeksztalca na zmienna z cechami wilomianowymi, czyli z = [1, x, x^2] z komorki powyzej
X_poly
# Out:
# array([[  1.  , -10.  , 100.  ],
#        [  1.  ,  -9.5 ,  90.25],
#        [  1.  ,  -9.  ,  81.  ],
#        [  1.  ,  -8.5 ,  72.25],
#        [  1.  ,  -8.  ,  64.  ],
#        [  1.  ,  -7.5 ,  56.25],
#        [  1.  ,  -7.  ,  49.  ],
#        [  1.  ,  -6.5 ,  42.25],
#        [  1.  ,  -6.  ,  36.  ],
#        [  1.  ,  -5.5 ,  30.25],
#        [  1.  ,  -5.  ,  25.  ],
#        [  1.  ,  -4.5 ,  20.25],
#        [  1.  ,  -4.  ,  16.  ],
#        [  1.  ,  -3.5 ,  12.25],
#        [  1.  ,  -3.  ,   9.  ],
#        [  1.  ,  -2.5 ,   6.25],
#        [  1.  ,  -2.  ,   4.  ],
#        [  1.  ,  -1.5 ,   2.25],
#        [  1.  ,  -1.  ,   1.  ],
#        [  1.  ,  -0.5 ,   0.25],
#        [  1.  ,   0.  ,   0.  ],
#        [  1.  ,   0.5 ,   0.25],
#        [  1.  ,   1.  ,   1.  ],
#        [  1.  ,   1.5 ,   2.25],
#        [  1.  ,   2.  ,   4.  ],
#        [  1.  ,   2.5 ,   6.25],
#        [  1.  ,   3.  ,   9.  ],
#        [  1.  ,   3.5 ,  12.25],
#        [  1.  ,   4.  ,  16.  ],
#        [  1.  ,   4.5 ,  20.25],
#        [  1.  ,   5.  ,  25.  ],
#        [  1.  ,   5.5 ,  30.25],
#        [  1.  ,   6.  ,  36.  ],
#        [  1.  ,   6.5 ,  42.25],
#        [  1.  ,   7.  ,  49.  ],
#        [  1.  ,   7.5 ,  56.25],
#        [  1.  ,   8.  ,  64.  ],
#        [  1.  ,   8.5 ,  72.25],
#        [  1.  ,   9.  ,  81.  ],
#        [  1.  ,   9.5 ,  90.25]])

# %% [markdown]
# ## Dopasowanie modelu

# %%
regressor_poly = LinearRegression()
regressor_poly.fit(X_poly, y)

y_pred = regressor_poly.predict(X_poly)

plt.scatter(X, y)
plt.plot(X, y_pred, c='r')

# %%
r2_score(y, y_pred)
# Out:
# 0.9000601519884677

# %%
# wielomian stopnia 3
X_poly_3 = PolynomialFeatures(degree=3).fit_transform(X) #przeksztalca na zmienna z cechami wilomianowymi, czyli z = [1, x, x^2] z komorki powyzej

regressor_poly_3 = LinearRegression()
regressor_poly_3.fit(X_poly_3, y)
y_pred = regressor_poly_3.predict(X_poly_3)

plt.scatter(X, y)
plt.plot(X, y_pred, c='r')

# %%
# wielomian stopnia 10 (nie wiem czy ma sens)
X_poly_10 = PolynomialFeatures(degree=10).fit_transform(X) #przeksztalca na zmienna z cechami wilomianowymi, czyli z = [1, x, x^2] z komorki powyzej

regressor_poly_3 = LinearRegression()
regressor_poly_3.fit(X_poly_10, y)
y_pred = regressor_poly_3.predict(X_poly_10)

plt.scatter(X, y)
plt.plot(X, y_pred, c='r')
